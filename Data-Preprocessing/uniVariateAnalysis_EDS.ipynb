# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv('C:/Users/hp/Downloads/train.csv')

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.sample(10)
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 436          437         0       3  Ford, Miss. Doolina Margaret "Daisy"
# 815          816         0       1                      Fry, Mr. Richard
# 496          497         1       1        Eustis, Miss. Elizabeth Mussey
# 130          131         0       3                  Drazenoic, Mr. Jozef
# 207          208         1       3           Albimona, Mr. Nassef Cassem
# 211          212         1       2            Cameron, Miss. Clear Annie
# 510          511         1       3              Daly, Mr. Eugene Patrick
# 512          513         1       1             McGough, Mr. James Robert
# 393          394         1       1                Newell, Miss. Marjorie
# 280          281         0       3                      Duane, Mr. Frank
#
#         Sex   Age  SibSp  Parch        Ticket      Fare Cabin Embarked
# 436  female  21.0      2      2    W./C. 6608   34.3750   NaN        S
# 815    male   NaN      0      0        112058    0.0000  B102        S
# 496  female  54.0      1      0         36947   78.2667   D20        C
# 130    male  33.0      0      0        349241    7.8958   NaN        C
# 207    male  26.0      0      0          2699   18.7875   NaN        C
# 211  female  35.0      0      0  F.C.C. 13528   21.0000   NaN        S
# 510    male  29.0      0      0        382651    7.7500   NaN        Q
# 512    male  36.0      0      0      PC 17473   26.2875   E25        S
# 393  female  23.0      1      0         35273  113.2750   D36        C
# 280    male  65.0      0      0        336439    7.7500   NaN        Q

# %%
#to check null values
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df['Age']=df['Age'].fillna(0).astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          891 non-null    int32
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(1), int32(1), int64(5), object(5)
# memory usage: 80.2+ KB

# %%
# any duplicates
df.duplicated().sum()
# Out:
# 0

# %%
# correlation between cols
df.corr(numeric_only='True')
# Out:
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId     1.000000 -0.005007 -0.035144  0.038220 -0.057527 -0.001652
# Survived       -0.005007  1.000000 -0.338481  0.010508 -0.035322  0.081629
# Pclass         -0.035144 -0.338481  1.000000 -0.361566  0.083081  0.018443
# Age             0.038220  0.010508 -0.361566  1.000000 -0.184593 -0.049061
# SibSp          -0.057527 -0.035322  0.083081 -0.184593  1.000000  0.414838
# Parch          -0.001652  0.081629  0.018443 -0.049061  0.414838  1.000000
# Fare            0.012658  0.257307 -0.549500  0.135663  0.159651  0.216225
#
#                  Fare
# PassengerId  0.012658
# Survived     0.257307
# Pclass      -0.549500
# Age          0.135663
# SibSp        0.159651
# Parch        0.216225
# Fare         1.000000

# %%
# correlation between cols
df.corr(numeric_only='True')['Age']
# Out:
# PassengerId    0.038220
# Survived       0.010508
# Pclass        -0.361566
# Age            1.000000
# SibSp         -0.184593
# Parch         -0.049061
# Fare           0.135663
# Name: Age, dtype: float64

# %% [markdown]
# # 1. Categorical Data

# %% [markdown]
# ## a. Countplot

# %%
# sns.countplot(df['Pclass'])
# df['Survived']
df['Pclass'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Pclass'>

# %% [markdown]
# ## b. PieChart

# %%
df['Sex'].value_counts().plot(kind='pie',autopct='%.2f')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# <div style="border-top:black 2px solid"></div>

# %% [markdown]
# # 2. Numerical Data

# %% [markdown]
# ## a. Histogram

# %%
import matplotlib.pyplot as plt
plt.hist(df['Age'],bins=5)
# Out:
# (array([260., 345., 197.,  76.,  13.]),
#  array([ 0., 16., 32., 48., 64., 80.]),
#  <BarContainer object of 5 artists>)

# %% [markdown]
# ## b. Distplot

# %%
# hist+kde[kernel density estimaton-KDE] = distplot
sns.distplot(df['Age'])
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_27828\3255828239.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Age'])
# C:\Users\hp\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='Age', ylabel='Density'>

# %% [markdown]
# ## c. Boxplot

# %%
sns.boxplot(x=df['Age'])
# Out:
# <Axes: xlabel='Age'>

# %%
df['Age'].min()
# Out:
# 0

# %%
df['Age'].max()
# Out:
# 80

# %%
df['Age'].mean()
# Out:
# 23.783389450056116

# %%
df['Age'].skew()
# Out:
# 0.2621397631626044
